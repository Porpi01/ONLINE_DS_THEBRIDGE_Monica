# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
URI = 'postgresql://postgres:orders@104.155.72.77:5432/postgres' 
engine = create_engine(URI)

# %%
orders = pd.read_csv("Data Source.xlsx - Sheet1.csv",index_col="Row ID")
orders.to_sql(name='postgres', con=engine, if_exists='append', index=None)
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[16], line 2
#       1 orders = pd.read_csv("Data Source.xlsx - Sheet1.csv",index_col="Row ID")
# ----> 2 orders.to_sql(name='postgres', con=engine, if_exists='append', index=None)
#
# File c:\Users\Usuario\miniconda3\envs\data_analysis_env\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
orders
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 3       CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 4       US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...                ...         ...         ...             ...         ...
# 9990    CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9991    CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9992    CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9993    CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9994    CA-2017-119914    5/4/2017    5/9/2017    Second Class    CC-12220
#
# ...
